# %% [markdown]
# tweepy
#
# Official documentation: https://docs.tweepy.org/en/stable/
#
# Ref: https://dev.to/twitterdev/a-comprehensive-guide-for-using-the-twitter-api-v2-using-tweepy-in-python-15d9

# %%
import tweepy
import datetime
import pandas as pd
import json
import requests

# %%
# Paste in your own bearer token
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAK4QlQEAAAAALR2CuS1t8%2BSL5VUIS8BZhA61jNI%3DArMOmsZoDiebtzyFOCTmcgwQK6wKQJ099SLHywiAnEwJzCTYOy'

client = tweepy.Client(bearer_token=BEARER_TOKEN, return_type=requests.Response)

# %%
'''
Searching for Tweets from the last 7 days

We can use the search_recent_tweets function available in Tweepy.
You will have to pass it a search query to specify the data that you are looking for.

Below, we will search for for Tweets from the last days from the 
Twitter handle realDonaldTrump and we are excluding retweets using -is:retweet.

By default, a request returns 10 Tweets.
If you want more than 10 Tweets per request, you can specify that using the max_results parameter.
The maximum Tweets per request is 100.
'''
# Replace with your own search query
handle = 'KimKardashian'
query = 'from:' + handle + ' -is:retweet'

tweets1 = client.search_recent_tweets(
            query=query,
            tweet_fields=['context_annotations', 'created_at'],
            max_results=100)

# %%
'''
Convert to pandas Dataframe
'''

# Save data as dictionary
tweets_dict1 = tweets1.json()

# Extract "data" value from dictionary
tweets_data1 = tweets_dict1['data'] 

# Transform to pandas Dataframe
df1 = pd.json_normalize(tweets_data1)

df1
# Out:
#                  created_at                   id  \
# 0  2023-01-29T22:27:52.000Z  1619824677983232002
# 1  2023-01-27T18:00:04.000Z  1619032505977552897
# 2  2023-01-26T18:07:01.000Z  1618671867539386370
# 3  2023-01-25T19:00:04.000Z  1618322832194433025
# 4  2023-01-24T20:17:53.000Z  1617980024652705792
#
#                                  context_annotations edit_history_tweet_ids  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...  [1619824677983232002]
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  [1619032505977552897]
# 2  [{'domain': {'id': '10', 'name': 'Person', 'de...  [1618671867539386370]
# 3  [{'domain': {'id': '10', 'name': 'Person', 'de...  [1618322832194433025]
# 4  [{'domain': {'id': '10', 'name': 'Person', 'de...  [1617980024652705792]
#
#                                                 text
# 0  when life gets blurry…adjust your focus https:...
# 1  Just added new items on my #KardashianKloset! ...
# 2  “So much involved with what has evolved” - Nic...
# 3  My little Chi Chi’s Hello Kitty Birthday party...
# 4  Introducing the Vanity Bag from @SKKN BY KIM —...

# %%
'''
If you want to get Tweets for a specific time-period, you can specify the time-period
using the start_time and end_time parameters, as shown in the example below:
'''

# Replace with time period of your choice
start_time = '2023-01-25T00:00:00Z'

# Replace with time period of your choice
end_time = '2023-01-3T00:00:00Z'


# Replace with your own search query
handle = 'elonmusk'
query = 'from:' + handle + ' -is:retweet'

tweets2 = client.search_recent_tweets(
            query=query,
            tweet_fields=['context_annotations', 'created_at'],
            start_time=start_time,
            end_time=end_time,
            max_results=100)

'''
Convert to pandas Dataframe
'''
df2 = pd.json_normalize(tweets2)

tweets2.json()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In[5], line 17
#      14 handle = 'elonmusk'
#      15 query = 'from:' + handle + ' -is:retweet'
# ---> 17 tweets2 = client.search_recent_tweets(
#      18             query=query,
#      19             tweet_fields=['context_annotations', 'created_at'],
#      20             start_time=start_time,
#      21             end_time=end_time,
#      22             max_results=100)
#      24 '''
#      25 Convert to pandas Dataframe
#      26 '''
#      27 df2 = pd.json_normalize(tweets2)
#
# File ~\Anaconda3\envs\py39\lib\site-packages\tweepy\client.py:1266, in Client.search_recent_tweets(self, query, user_auth, **params)
#    1174 """search_recent_tweets( \
#    1175     query, *, end_time=None, expansions=None, max_results=None, \
#    1176     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1263 .. _Academic Research Project: https://developer.twitter.com/en/docs/projects
#    1264 """
#    1265 params["query"] = query
# -> 1266 return self._make_request(
#    1267     "GET", "/2/tweets/search/recent", params=params,
#    1268     endpoint_parameters=(
#    1269         "end_time", "expansions", "max_results", "media.fields",
#    1270         "next_token", "place.fields", "poll.fields", "query",
#    1271         "since_id", "sort_order", "start_time", "tweet.fields",
#    1272         "until_id", "user.fields"
#    1273     ), data_type=Tweet, user_auth=user_auth
#    1274 )
#
# File ~\Anaconda3\envs\py39\lib\site-packages\tweepy\client.py:129, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     123 def _make_request(
#     124     self, method, route, params={}, endpoint_parameters=(), json=None,
#     125     data_type=None, user_auth=False
#     126 ):
#     127     request_params = self._process_params(params, endpoint_parameters)
# --> 129     response = self.request(method, route, params=request_params,
#     130                             json=json, user_auth=user_auth)
#     132     if self.return_type is requests.Response:
#     133         return response
#
# File ~\Anaconda3\envs\py39\lib\site-packages\tweepy\client.py:96, in BaseClient.request(self, method, route, params, json, user_auth)
#      88 log.debug(
#      89     "Received API response: "
#      90     f"{response.status_code} {response.reason}\n"
#      91     f"Headers: {response.headers}\n"
#      92     f"Content: {response.content}"
#      93 )
#      95 if response.status_code == 400:
# ---> 96     raise BadRequest(response)
#      97 if response.status_code == 401:
#      98     raise Unauthorized(response)
#
# BadRequest: 400 Bad Request
# Invalid 'start_time':'2022-01-20T00:00Z'. 'start_time' must be on or after 2023-01-24T06:56Z
# Invalid 'end_time':'2022-01-25T00:00Z'. 'end_time' must be on or after 2023-01-24T06:56Z

# %%
'''
Writing Tweets to a text file

This example shows how you can write the Tweet IDs for each Tweet obtained 
for a search result, to a text file.

Make sure to replace the file_name with the a name of your chosing.

If you wish to write other fields to the text file, make sure to adjust the script below accordingly.
'''

file_name = 'tweets.txt'

df2.to_csv(file_name, index=False, encoding='utf-8')

# If you want a different delimiter, say, tab or '\t'
# You can do:
#    df2.to_csv(file_name, index=False, encoding='utf-8', sep='\t')
